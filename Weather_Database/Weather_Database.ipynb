# %%
from citipy import citipy
import numpy as np
import pandas as pd
import requests
import time

# %%
# Import the API keys from config
import sys
import os

# get name of this directory
current = os.path.dirname(os.path.realpath('Weather_Database'))

# get name of the parent directory
parent = os.path.dirname(current)

# adding parent directory to the sys.path
sys.path.append(parent)

# importing config
from config import weather_api_key

# %%
# Stating URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Combining lats and lngs in a zip
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
# Converting from zip to list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 790

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_desc = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | cap malheureux
# Processing Record 6 of Set 1 | wisconsin rapids
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | pangnirtung
# Processing Record 9 of Set 1 | valdez
# Processing Record 10 of Set 1 | genhe
# Processing Record 11 of Set 1 | huarmey
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | zaterechnyy
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | divnomorskoye
# Processing Record 16 of Set 1 | winton
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | elizabeth city
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | mana
# Processing Record 22 of Set 1 | samarai
# Processing Record 23 of Set 1 | kalavad
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | port blair
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | batagay-alyta
# Processing Record 29 of Set 1 | terrace
# Processing Record 30 of Set 1 | anloga
# Processing Record 31 of Set 1 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | carutapera
# Processing Record 34 of Set 1 | dossor
# Processing Record 35 of Set 1 | zhangye
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | alofi
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | kendari
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | fortuna
# Processing Record 43 of Set 1 | leh
# Processing Record 44 of Set 1 | opuwo
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | coahuayana
# Processing Record 47 of Set 1 | buraydah
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | gambela
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | nyurba
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | palpa
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | hofn
# Processing Record 8 of Set 2 | chernyshevskiy
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | pishva
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | dibulla
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | fugen
# Processing Record 15 of Set 2 | adrar
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | mount isa
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | polunochnoye
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | ornskoldsvik
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | dumas
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | porto novo
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | yar-sale
# Processing Record 36 of Set 2 | carballo
# Processing Record 37 of Set 2 | wamba
# Processing Record 38 of Set 2 | matagami
# Processing Record 39 of Set 2 | murdochville
# Processing Record 40 of Set 2 | baykit
# Processing Record 41 of Set 2 | filingue
# Processing Record 42 of Set 2 | sidhi
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | rognan
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | chapais
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | sao joao da barra
# Processing Record 50 of Set 2 | fort nelson
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | chipiona
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | ossora
# Processing Record 5 of Set 3 | srednekolymsk
# Processing Record 6 of Set 3 | demidov
# Processing Record 7 of Set 3 | constitucion
# Processing Record 8 of Set 3 | meulaboh
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | bennington
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | lampazos de naranjo
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | nata
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | dicabisagan
# Processing Record 17 of Set 3 | hay river
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | nemuro
# Processing Record 21 of Set 3 | price
# Processing Record 22 of Set 3 | komsomolskiy
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | san patricio
# Processing Record 25 of Set 3 | manado
# Processing Record 26 of Set 3 | los algarrobos
# Processing Record 27 of Set 3 | aykhal
# Processing Record 28 of Set 3 | jumla
# Processing Record 29 of Set 3 | syamzha
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | mahon
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | polyarnyye zori
# Processing Record 34 of Set 3 | norman wells
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | bagdarin
# Processing Record 37 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 3 | mae sai
# Processing Record 39 of Set 3 | yerbogachen
# Processing Record 40 of Set 3 | maridi
# Processing Record 41 of Set 3 | bereda
# Processing Record 42 of Set 3 | tazovskiy
# Processing Record 43 of Set 3 | colares
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | comodoro rivadavia
# Processing Record 46 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 3 | sarangani
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | padang
# Processing Record 1 of Set 4 | faya
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | roald
# Processing Record 4 of Set 4 | porto
# Processing Record 5 of Set 4 | avera
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | praia
# Processing Record 8 of Set 4 | honningsvag
# Processing Record 9 of Set 4 | port hedland
# Processing Record 10 of Set 4 | san miguel
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | oda
# Processing Record 13 of Set 4 | ninotsminda
# Processing Record 14 of Set 4 | ostersund
# Processing Record 15 of Set 4 | lanzhou
# Processing Record 16 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 4 | coihaique
# Processing Record 18 of Set 4 | macia
# Processing Record 19 of Set 4 | vysokogornyy
# Processing Record 20 of Set 4 | bilma
# Processing Record 21 of Set 4 | saint anthony
# Processing Record 22 of Set 4 | bustonkala
# City not found. Skipping...
# Processing Record 23 of Set 4 | yarmouth
# Processing Record 24 of Set 4 | haines junction
# Processing Record 25 of Set 4 | zarubino
# Processing Record 26 of Set 4 | changping
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | nabire
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | parauna
# Processing Record 31 of Set 4 | sosua
# Processing Record 32 of Set 4 | sawtell
# Processing Record 33 of Set 4 | kutum
# Processing Record 34 of Set 4 | raglan
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | egvekinot
# Processing Record 37 of Set 4 | vicuna
# Processing Record 38 of Set 4 | santa rosa
# Processing Record 39 of Set 4 | palmer
# Processing Record 40 of Set 4 | zhangjiakou
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | sahbuz
# Processing Record 43 of Set 4 | dunedin
# Processing Record 44 of Set 4 | ketchikan
# Processing Record 45 of Set 4 | namatanai
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | belaya gora
# Processing Record 48 of Set 4 | ruidoso
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | salalah
# Processing Record 1 of Set 5 | henties bay
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | berdigestyakh
# Processing Record 4 of Set 5 | belmonte
# Processing Record 5 of Set 5 | azare
# Processing Record 6 of Set 5 | selma
# Processing Record 7 of Set 5 | colesberg
# Processing Record 8 of Set 5 | songea
# Processing Record 9 of Set 5 | narsaq
# Processing Record 10 of Set 5 | pyrzyce
# Processing Record 11 of Set 5 | butaritari
# Processing Record 12 of Set 5 | ulladulla
# Processing Record 13 of Set 5 | porto torres
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | stokmarknes
# Processing Record 16 of Set 5 | gravdal
# Processing Record 17 of Set 5 | kattivakkam
# Processing Record 18 of Set 5 | nuuk
# Processing Record 19 of Set 5 | brae
# Processing Record 20 of Set 5 | sioux lookout
# Processing Record 21 of Set 5 | namibe
# Processing Record 22 of Set 5 | oxford
# Processing Record 23 of Set 5 | slevik
# City not found. Skipping...
# Processing Record 24 of Set 5 | port hueneme
# Processing Record 25 of Set 5 | vangaindrano
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | buchanan
# Processing Record 28 of Set 5 | praia da vitoria
# Processing Record 29 of Set 5 | wadi maliz
# Processing Record 30 of Set 5 | codrington
# Processing Record 31 of Set 5 | dekar
# Processing Record 32 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | kisiwani
# Processing Record 35 of Set 5 | inirida
# Processing Record 36 of Set 5 | upernavik
# Processing Record 37 of Set 5 | ondjiva
# Processing Record 38 of Set 5 | ugoofaaru
# Processing Record 39 of Set 5 | barabai
# Processing Record 40 of Set 5 | isiolo
# Processing Record 41 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 5 | vestmannaeyjar
# Processing Record 43 of Set 5 | teguldet
# Processing Record 44 of Set 5 | marsaxlokk
# Processing Record 45 of Set 5 | nome
# Processing Record 46 of Set 5 | batticaloa
# Processing Record 47 of Set 5 | leutkirch
# Processing Record 48 of Set 5 | flinders
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | filadelfia
# Processing Record 1 of Set 6 | tokur
# Processing Record 2 of Set 6 | bambanglipuro
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | tebingtinggi
# Processing Record 5 of Set 6 | acobamba
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | victoria
# Processing Record 8 of Set 6 | sorong
# Processing Record 9 of Set 6 | mackay
# Processing Record 10 of Set 6 | chuy
# Processing Record 11 of Set 6 | marsh harbour
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | lagoa
# Processing Record 14 of Set 6 | beringovskiy
# Processing Record 15 of Set 6 | saposoa
# Processing Record 16 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 6 | kodiak
# Processing Record 18 of Set 6 | kloulklubed
# Processing Record 19 of Set 6 | poum
# Processing Record 20 of Set 6 | sjovegan
# Processing Record 21 of Set 6 | santa cruz cabralia
# Processing Record 22 of Set 6 | swellendam
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | carlisle
# Processing Record 25 of Set 6 | marzuq
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | tukrah
# Processing Record 29 of Set 6 | kashirskoye
# Processing Record 30 of Set 6 | gasa
# Processing Record 31 of Set 6 | senneterre
# Processing Record 32 of Set 6 | hambantota
# Processing Record 33 of Set 6 | kananga
# Processing Record 34 of Set 6 | bure
# Processing Record 35 of Set 6 | san marcos
# Processing Record 36 of Set 6 | saint-georges
# Processing Record 37 of Set 6 | havre-saint-pierre
# Processing Record 38 of Set 6 | aklavik
# Processing Record 39 of Set 6 | khorixas
# Processing Record 40 of Set 6 | palembang
# Processing Record 41 of Set 6 | pochutla
# Processing Record 42 of Set 6 | pandan
# Processing Record 43 of Set 6 | piopio
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | penzance
# Processing Record 46 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 6 | bilibino
# Processing Record 48 of Set 6 | maldonado
# Processing Record 49 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 6 | dana point
# Processing Record 1 of Set 7 | mwanga
# Processing Record 2 of Set 7 | thanh hoa
# Processing Record 3 of Set 7 | port hardy
# Processing Record 4 of Set 7 | juneau
# Processing Record 5 of Set 7 | mogadishu
# Processing Record 6 of Set 7 | saint-francois
# Processing Record 7 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | irbil
# Processing Record 10 of Set 7 | tutoia
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | himora
# City not found. Skipping...
# Processing Record 13 of Set 7 | lantawan
# Processing Record 14 of Set 7 | segou
# Processing Record 15 of Set 7 | touros
# Processing Record 16 of Set 7 | grenfell
# Processing Record 17 of Set 7 | valkeala
# Processing Record 18 of Set 7 | acarau
# Processing Record 19 of Set 7 | la romana
# Processing Record 20 of Set 7 | moerai
# Processing Record 21 of Set 7 | aksarka
# Processing Record 22 of Set 7 | sola
# Processing Record 23 of Set 7 | tessalit
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | ereymentau
# Processing Record 26 of Set 7 | sorland
# Processing Record 27 of Set 7 | mirnyy
# Processing Record 28 of Set 7 | tamparan
# Processing Record 29 of Set 7 | xai-xai
# Processing Record 30 of Set 7 | ovalle
# Processing Record 31 of Set 7 | ilo
# Processing Record 32 of Set 7 | bathsheba
# Processing Record 33 of Set 7 | oktyabrskiy
# Processing Record 34 of Set 7 | seoul
# Processing Record 35 of Set 7 | muros
# Processing Record 36 of Set 7 | caravelas
# Processing Record 37 of Set 7 | nador
# Processing Record 38 of Set 7 | georgetown
# Processing Record 39 of Set 7 | cockburn town
# Processing Record 40 of Set 7 | pingdingshan
# Processing Record 41 of Set 7 | baherden
# Processing Record 42 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 7 | tezu
# Processing Record 44 of Set 7 | kushmurun
# Processing Record 45 of Set 7 | noumea
# Processing Record 46 of Set 7 | torbay
# Processing Record 47 of Set 7 | qaqortoq
# Processing Record 48 of Set 7 | union hidalgo
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | kambove
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | umm kaddadah
# Processing Record 3 of Set 8 | maarianhamina
# Processing Record 4 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 8 | kerouane
# Processing Record 6 of Set 8 | ham lake
# Processing Record 7 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 8 | shitanjing
# Processing Record 9 of Set 8 | yulara
# Processing Record 10 of Set 8 | buluang
# Processing Record 11 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 8 | launceston
# Processing Record 13 of Set 8 | manokwari
# Processing Record 14 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 8 | zatoka
# Processing Record 16 of Set 8 | aasiaat
# Processing Record 17 of Set 8 | adwa
# Processing Record 18 of Set 8 | sao filipe
# Processing Record 19 of Set 8 | bridlington
# Processing Record 20 of Set 8 | abu kamal
# Processing Record 21 of Set 8 | panguipulli
# Processing Record 22 of Set 8 | pisco
# Processing Record 23 of Set 8 | arlit
# Processing Record 24 of Set 8 | labuhan
# Processing Record 25 of Set 8 | ambulu
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | bonthe
# Processing Record 28 of Set 8 | goderich
# Processing Record 29 of Set 8 | pemba
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | tambovka
# Processing Record 32 of Set 8 | port augusta
# Processing Record 33 of Set 8 | loandjili
# Processing Record 34 of Set 8 | oudtshoorn
# Processing Record 35 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 8 | laksham
# Processing Record 37 of Set 8 | eyl
# Processing Record 38 of Set 8 | pirmasens
# Processing Record 39 of Set 8 | mandalgovi
# Processing Record 40 of Set 8 | korla
# Processing Record 41 of Set 8 | alenquer
# Processing Record 42 of Set 8 | cuamba
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 8 | port elizabeth
# Processing Record 46 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 47 of Set 8 | lavumisa
# Processing Record 48 of Set 8 | saskylakh
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | belyy yar
# Processing Record 1 of Set 9 | amahai
# Processing Record 2 of Set 9 | bom jesus
# Processing Record 3 of Set 9 | high level
# Processing Record 4 of Set 9 | pacific grove
# Processing Record 5 of Set 9 | poso
# Processing Record 6 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 9 | huicungo
# Processing Record 8 of Set 9 | banjar
# Processing Record 9 of Set 9 | soe
# Processing Record 10 of Set 9 | novo aripuana
# Processing Record 11 of Set 9 | cashel
# Processing Record 12 of Set 9 | atar
# Processing Record 13 of Set 9 | maisyan
# City not found. Skipping...
# Processing Record 14 of Set 9 | stromness
# Processing Record 15 of Set 9 | chara
# Processing Record 16 of Set 9 | port-gentil
# Processing Record 17 of Set 9 | jamame
# Processing Record 18 of Set 9 | savannah bight
# Processing Record 19 of Set 9 | kamenka
# Processing Record 20 of Set 9 | ambilobe
# Processing Record 21 of Set 9 | ayan
# Processing Record 22 of Set 9 | ilulissat
# Processing Record 23 of Set 9 | half moon bay
# Processing Record 24 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 9 | baijiantan
# Processing Record 27 of Set 9 | cherskiy
# Processing Record 28 of Set 9 | sterling
# Processing Record 29 of Set 9 | tairua
# Processing Record 30 of Set 9 | saint-pierre
# Processing Record 31 of Set 9 | luanda
# Processing Record 32 of Set 9 | akhmim
# Processing Record 33 of Set 9 | dulce nombre de culmi
# Processing Record 34 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 9 | minot
# Processing Record 36 of Set 9 | linxia
# Processing Record 37 of Set 9 | hamilton
# Processing Record 38 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 9 | ankazoabo
# Processing Record 40 of Set 9 | jalingo
# Processing Record 41 of Set 9 | tigil
# Processing Record 42 of Set 9 | abha
# Processing Record 43 of Set 9 | los llanos de aridane
# Processing Record 44 of Set 9 | pontianak
# Processing Record 45 of Set 9 | svetlaya
# Processing Record 46 of Set 9 | manta
# Processing Record 47 of Set 9 | esperance
# Processing Record 48 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 10 | tucuman
# Processing Record 2 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 10 | luchegorsk
# Processing Record 4 of Set 10 | kodinsk
# Processing Record 5 of Set 10 | bima
# Processing Record 6 of Set 10 | laguna
# Processing Record 7 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 10 | san carlos de bariloche
# Processing Record 9 of Set 10 | bizhbulyak
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | maneadero
# Processing Record 14 of Set 10 | chekmagush
# Processing Record 15 of Set 10 | arawa
# Processing Record 16 of Set 10 | harper
# Processing Record 17 of Set 10 | boguchany
# Processing Record 18 of Set 10 | dongning
# Processing Record 19 of Set 10 | dikson
# Processing Record 20 of Set 10 | rhyl
# Processing Record 21 of Set 10 | nouadhibou
# Processing Record 22 of Set 10 | salym
# Processing Record 23 of Set 10 | kimberley
# Processing Record 24 of Set 10 | miri
# Processing Record 25 of Set 10 | acajutla
# Processing Record 26 of Set 10 | pittsburg
# Processing Record 27 of Set 10 | laurel
# Processing Record 28 of Set 10 | zadar
# Processing Record 29 of Set 10 | ixtapa
# Processing Record 30 of Set 10 | kempen
# Processing Record 31 of Set 10 | ararat
# Processing Record 32 of Set 10 | okhotsk
# Processing Record 33 of Set 10 | kemijarvi
# Processing Record 34 of Set 10 | setermoen
# Processing Record 35 of Set 10 | acapulco
# Processing Record 36 of Set 10 | teya
# Processing Record 37 of Set 10 | nova olinda do norte
# Processing Record 38 of Set 10 | dingle
# Processing Record 39 of Set 10 | la asuncion
# Processing Record 40 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 41 of Set 10 | evensk
# Processing Record 42 of Set 10 | sabang
# Processing Record 43 of Set 10 | hammerfest
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | nadym
# Processing Record 46 of Set 10 | calama
# Processing Record 47 of Set 10 | beira
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | kyren
# Processing Record 50 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 11 | balykshi
# Processing Record 2 of Set 11 | hovd
# Processing Record 3 of Set 11 | kirakira
# Processing Record 4 of Set 11 | ocampo
# Processing Record 5 of Set 11 | suwalki
# Processing Record 6 of Set 11 | provideniya
# Processing Record 7 of Set 11 | dudinka
# Processing Record 8 of Set 11 | la tuque
# Processing Record 9 of Set 11 | sembe
# Processing Record 10 of Set 11 | lewiston
# Processing Record 11 of Set 11 | moose factory
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | qostanay
# Processing Record 14 of Set 11 | waipawa
# Processing Record 15 of Set 11 | mwinilunga
# Processing Record 16 of Set 11 | waingapu
# Processing Record 17 of Set 11 | vila do maio
# Processing Record 18 of Set 11 | koulikoro
# Processing Record 19 of Set 11 | talnakh
# Processing Record 20 of Set 11 | asau
# Processing Record 21 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 22 of Set 11 | honiara
# Processing Record 23 of Set 11 | smolenka
# Processing Record 24 of Set 11 | tongchuan
# Processing Record 25 of Set 11 | rio brilhante
# Processing Record 26 of Set 11 | primero de marzo
# Processing Record 27 of Set 11 | zhuhai
# Processing Record 28 of Set 11 | nouakchott
# Processing Record 29 of Set 11 | alpena
# Processing Record 30 of Set 11 | tual
# Processing Record 31 of Set 11 | cauquenes
# Processing Record 32 of Set 11 | redding
# Processing Record 33 of Set 11 | kharan
# Processing Record 34 of Set 11 | lyngseidet
# Processing Record 35 of Set 11 | krasnovishersk
# Processing Record 36 of Set 11 | batsfjord
# Processing Record 37 of Set 11 | lompoc
# Processing Record 38 of Set 11 | shellbrook
# Processing Record 39 of Set 11 | ulundi
# Processing Record 40 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 11 | leglise
# Processing Record 42 of Set 11 | denia
# Processing Record 43 of Set 11 | leningradskiy
# Processing Record 44 of Set 11 | krasnyy chikoy
# Processing Record 45 of Set 11 | flin flon
# Processing Record 46 of Set 11 | gitarama
# Processing Record 47 of Set 11 | chauk
# Processing Record 48 of Set 11 | sinjah
# City not found. Skipping...
# Processing Record 49 of Set 11 | scalloway
# City not found. Skipping...
# Processing Record 50 of Set 11 | lugovskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | guhagar
# Processing Record 2 of Set 12 | mehamn
# Processing Record 3 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 4 of Set 12 | keuruu
# Processing Record 5 of Set 12 | kapoeta
# Processing Record 6 of Set 12 | saint-joseph
# Processing Record 7 of Set 12 | hudson bay
# Processing Record 8 of Set 12 | fort saint james
# Processing Record 9 of Set 12 | port-cartier
# Processing Record 10 of Set 12 | moyale
# Processing Record 11 of Set 12 | paredon
# Processing Record 12 of Set 12 | forbes
# Processing Record 13 of Set 12 | aracoiaba da serra
# Processing Record 14 of Set 12 | druzhba
# Processing Record 15 of Set 12 | abu samrah
# Processing Record 16 of Set 12 | hervey bay
# Processing Record 17 of Set 12 | jalu
# Processing Record 18 of Set 12 | endicott
# Processing Record 19 of Set 12 | sayyan
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | akyab
# Processing Record 22 of Set 12 | praya
# Processing Record 23 of Set 12 | beloha
# Processing Record 24 of Set 12 | turka
# Processing Record 25 of Set 12 | aquiraz
# Processing Record 26 of Set 12 | oyugis
# Processing Record 27 of Set 12 | matara
# Processing Record 28 of Set 12 | olafsvik
# Processing Record 29 of Set 12 | rovaniemi
# Processing Record 30 of Set 12 | verkhnyaya inta
# Processing Record 31 of Set 12 | lata
# Processing Record 32 of Set 12 | boende
# Processing Record 33 of Set 12 | botwood
# Processing Record 34 of Set 12 | council bluffs
# Processing Record 35 of Set 12 | rapid valley
# Processing Record 36 of Set 12 | grua
# Processing Record 37 of Set 12 | cam ranh
# Processing Record 38 of Set 12 | luorong
# Processing Record 39 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 40 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 12 | campbell river
# Processing Record 42 of Set 12 | mpika
# Processing Record 43 of Set 12 | lincoln
# Processing Record 44 of Set 12 | dongsheng
# Processing Record 45 of Set 12 | sesheke
# Processing Record 46 of Set 12 | katsuura
# Processing Record 47 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 12 | nyuksenitsa
# Processing Record 49 of Set 12 | catuday
# Processing Record 50 of Set 12 | bunia
# Processing Record 1 of Set 13 | toora-khem
# Processing Record 2 of Set 13 | towada
# Processing Record 3 of Set 13 | boyolangu
# Processing Record 4 of Set 13 | melita
# Processing Record 5 of Set 13 | mnogovershinnyy
# Processing Record 6 of Set 13 | the valley
# Processing Record 7 of Set 13 | sistranda
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | neryungri
# Processing Record 10 of Set 13 | domvraina
# Processing Record 11 of Set 13 | victor harbor
# Processing Record 12 of Set 13 | borba
# Processing Record 13 of Set 13 | shimoda
# Processing Record 14 of Set 13 | poykovskiy
# Processing Record 15 of Set 13 | canico
# Processing Record 16 of Set 13 | iracoubo
# Processing Record 17 of Set 13 | rock sound
# Processing Record 18 of Set 13 | cidreira
# Processing Record 19 of Set 13 | crotone
# Processing Record 20 of Set 13 | vila velha
# Processing Record 21 of Set 13 | purpe
# Processing Record 22 of Set 13 | ewa beach
# Processing Record 23 of Set 13 | bonavista
# Processing Record 24 of Set 13 | santa ana
# Processing Record 25 of Set 13 | bandarbeyla
# Processing Record 26 of Set 13 | byron bay
# Processing Record 27 of Set 13 | itarema
# Processing Record 28 of Set 13 | maniitsoq
# Processing Record 29 of Set 13 | thinadhoo
# Processing Record 30 of Set 13 | midrand
# Processing Record 31 of Set 13 | nizhniy kuranakh
# Processing Record 32 of Set 13 | coihueco
# Processing Record 33 of Set 13 | poli
# Processing Record 34 of Set 13 | shache
# Processing Record 35 of Set 13 | yangjiang
# Processing Record 36 of Set 13 | marsabit
# Processing Record 37 of Set 13 | santa lucia
# Processing Record 38 of Set 13 | terre-de-bas
# Processing Record 39 of Set 13 | kurilsk
# Processing Record 40 of Set 13 | acuitzio
# Processing Record 41 of Set 13 | alvor
# Processing Record 42 of Set 13 | fougamou
# Processing Record 43 of Set 13 | tambura
# Processing Record 44 of Set 13 | serafimovich
# Processing Record 45 of Set 13 | paita
# Processing Record 46 of Set 13 | champerico
# Processing Record 47 of Set 13 | ambon
# Processing Record 48 of Set 13 | krasnoslobodsk
# Processing Record 49 of Set 13 | lufilufi
# Processing Record 50 of Set 13 | urulga
# City not found. Skipping...
# Processing Record 1 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 14 | torres
# Processing Record 3 of Set 14 | sweetwater
# Processing Record 4 of Set 14 | shingu
# Processing Record 5 of Set 14 | virginia beach
# Processing Record 6 of Set 14 | kosh-agach
# Processing Record 7 of Set 14 | natal
# Processing Record 8 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 14 | gamba
# Processing Record 10 of Set 14 | clarence town
# Processing Record 11 of Set 14 | columbus
# Processing Record 12 of Set 14 | rabo de peixe
# Processing Record 13 of Set 14 | alanya
# Processing Record 14 of Set 14 | isangel
# Processing Record 15 of Set 14 | madang
# Processing Record 16 of Set 14 | araouane
# Processing Record 17 of Set 14 | san pedro de macoris
# Processing Record 18 of Set 14 | obo
# Processing Record 19 of Set 14 | pauini
# Processing Record 20 of Set 14 | khasan
# Processing Record 21 of Set 14 | raudeberg
# Processing Record 22 of Set 14 | ngama
# Processing Record 23 of Set 14 | ngunguru
# Processing Record 24 of Set 14 | hami
# Processing Record 25 of Set 14 | ballina
# Processing Record 26 of Set 14 | camacha
# Processing Record 27 of Set 14 | sept-iles
# Processing Record 28 of Set 14 | ahome
# Processing Record 29 of Set 14 | krasnoarmeysk
# Processing Record 30 of Set 14 | mackenzie
# Processing Record 31 of Set 14 | rawa mazowiecka
# Processing Record 32 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 33 of Set 14 | pemangkat
# Processing Record 34 of Set 14 | griffith
# Processing Record 35 of Set 14 | dedza
# Processing Record 36 of Set 14 | kruisfontein
# Processing Record 37 of Set 14 | nishihara
# Processing Record 38 of Set 14 | amapa
# Processing Record 39 of Set 14 | alyangula
# Processing Record 40 of Set 14 | bongandanga
# Processing Record 41 of Set 14 | buenos aires
# Processing Record 42 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 14 | mitsamiouli
# Processing Record 44 of Set 14 | buala
# Processing Record 45 of Set 14 | coxim
# Processing Record 46 of Set 14 | broome
# Processing Record 47 of Set 14 | torrington
# Processing Record 48 of Set 14 | rocha
# Processing Record 49 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 14 | itoman
# Processing Record 1 of Set 15 | gwadar
# Processing Record 2 of Set 15 | bardiyah
# Processing Record 3 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 15 | souillac
# Processing Record 5 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 6 of Set 15 | corning
# Processing Record 7 of Set 15 | khanpur
# Processing Record 8 of Set 15 | marystown
# Processing Record 9 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 15 | russell
# Processing Record 11 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 12 of Set 15 | zhezkazgan
# Processing Record 13 of Set 15 | salatiga
# Processing Record 14 of Set 15 | rincon
# Processing Record 15 of Set 15 | agadir
# Processing Record 16 of Set 15 | shubarshi
# Processing Record 17 of Set 15 | rio gallegos
# Processing Record 18 of Set 15 | sanandaj
# Processing Record 19 of Set 15 | nizwa
# Processing Record 20 of Set 15 | bethanien
# Processing Record 21 of Set 15 | poroshkovo
# Processing Record 22 of Set 15 | ola
# Processing Record 23 of Set 15 | talisayan
# Processing Record 24 of Set 15 | arys
# Processing Record 25 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 15 | madimba
# Processing Record 27 of Set 15 | acurenam
# Processing Record 28 of Set 15 | dukat
# Processing Record 29 of Set 15 | sagua la grande
# Processing Record 30 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 15 | ponta delgada
# Processing Record 32 of Set 15 | myitkyina
# Processing Record 33 of Set 15 | soyo
# Processing Record 34 of Set 15 | lethem
# Processing Record 35 of Set 15 | kununurra
# Processing Record 36 of Set 15 | saint-jerome
# Processing Record 37 of Set 15 | santa teresa
# Processing Record 38 of Set 15 | rawson
# Processing Record 39 of Set 15 | santa isabel
# Processing Record 40 of Set 15 | kedougou
# Processing Record 41 of Set 15 | luau
# Processing Record 42 of Set 15 | bac lieu
# Processing Record 43 of Set 15 | mitchell
# Processing Record 44 of Set 15 | moanda
# Processing Record 45 of Set 15 | aloleng
# Processing Record 46 of Set 15 | codajas
# Processing Record 47 of Set 15 | shirvan
# Processing Record 48 of Set 15 | orlik
# Processing Record 49 of Set 15 | alice springs
# Processing Record 50 of Set 15 | abnub
# Processing Record 1 of Set 16 | lunenburg
# Processing Record 2 of Set 16 | ishigaki
# Processing Record 3 of Set 16 | lazaro cardenas
# Processing Record 4 of Set 16 | mitu
# Processing Record 5 of Set 16 | vao
# Processing Record 6 of Set 16 | vestbygda
# City not found. Skipping...
# Processing Record 7 of Set 16 | sangar
# Processing Record 8 of Set 16 | teguise
# Processing Record 9 of Set 16 | mbandaka
# Processing Record 10 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 16 | kursk
# Processing Record 12 of Set 16 | marsa matruh
# Processing Record 13 of Set 16 | inhambane
# Processing Record 14 of Set 16 | wanning
# Processing Record 15 of Set 16 | methoni
# Processing Record 16 of Set 16 | lang son
# Processing Record 17 of Set 16 | biak
# Processing Record 18 of Set 16 | charlottetown
# Processing Record 19 of Set 16 | curup
# Processing Record 20 of Set 16 | varna
# Processing Record 21 of Set 16 | kushiro
# Processing Record 22 of Set 16 | sarti
# Processing Record 23 of Set 16 | winnemucca
# Processing Record 24 of Set 16 | svetlogorsk
# Processing Record 25 of Set 16 | black river
# Processing Record 26 of Set 16 | christchurch
# Processing Record 27 of Set 16 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 28 of Set 16 | la puebla del rio
# Processing Record 29 of Set 16 | wladyslawowo
# Processing Record 30 of Set 16 | coalinga
# Processing Record 31 of Set 16 | tepelene
# Processing Record 32 of Set 16 | lensk
# Processing Record 33 of Set 16 | maningrida
# Processing Record 34 of Set 16 | karratha
# Processing Record 35 of Set 16 | dolores
# Processing Record 36 of Set 16 | fort portal
# Processing Record 37 of Set 16 | devrek
# Processing Record 38 of Set 16 | galesong
# Processing Record 39 of Set 16 | guozhen
# Processing Record 40 of Set 16 | kirensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Busselton      AU -33.6500  115.3333     49.08        81
# 1           Rikitea      PF -23.1203 -134.9692     73.53        79
# 2       Clyde River      CA  70.4692  -68.5914     21.96        85
# 3    Ribeira Grande      PT  38.5167  -28.7000     70.20        88
# 4    Cap Malheureux      MU -19.9842   57.6142     71.47        76
# 5  Wisconsin Rapids      US  44.3836  -89.8174     50.45        52
# 6           Ahipara      NZ -35.1667  173.1667     58.35        93
# 7       Pangnirtung      CA  66.1451  -65.7125     17.33        77
# 8            Valdez      EC   1.2492  -78.9831     79.77        77
# 9             Genhe      CN  50.7833  121.5167     28.83        67
#
#    Cloudiness  Wind Speed Current Description
# 0          75        4.41       broken clouds
# 1         100       12.37          light rain
# 2         100       26.78          light snow
# 3          75       24.16       broken clouds
# 4           0        4.00           clear sky
# 5          40        6.91    scattered clouds
# 6         100        5.88          light rain
# 7         100        4.92     overcast clouds
# 8          20       10.29          few clouds
# 9         100        4.97     overcast clouds

# %%
# Create the output file (CSV) within Weather_Database directory
output_data_file = "./WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
